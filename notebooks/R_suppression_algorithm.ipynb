# %%
from bsp_epidemic_suppression_model.utilities.model import (
    make_scenario_parameters_for_asymptomatics_symptomatics_model,
)
from bsp_epidemic_suppression_model.utilities.scenario import Scenario
from bsp_epidemic_suppression_model.utilities.functions_utils import (
    DeltaMeasure,
    RealRange,
)
from bsp_epidemic_suppression_model.utilities.plotting_utils import plot_time_evolution
from bsp_epidemic_suppression_model.algorithm.time_evolution_with_severity import (
    compute_time_evolution_with_severity,
)

import warnings

warnings.filterwarnings("ignore")

# %%
# gs = [asymptomatic, symptomatic]
tau_max = 30
integration_step = 0.1

p_gs, r0_gs = make_scenario_parameters_for_asymptomatics_symptomatics_model()

scenario = Scenario(
    p_gs=p_gs,
    r0_gs=r0_gs,
    t_0=0,
    ssapp=[0, 0.2],
    ssnoapp=[0, 0.2],
    scapp=0.8,
    scnoapp=0.0,
    xi=0.9,
    papp=lambda tau: 0.6,
    p_DeltaATapp=DeltaMeasure(position=0),
    p_DeltaATnoapp=DeltaMeasure(position=0),
)

step_data_list = compute_time_evolution_with_severity(
    scenario=scenario,
    real_range=RealRange(0, tau_max, integration_step),
    n_iterations=6,
    verbose=True,
)

plot_time_evolution(step_data_list=step_data_list)
# Out:
# step 0, t_i=0
#  FAapp_ti_gs(infty)=[0.0, 0.2]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.12
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.12
#  FTapp_ti_gs(infty)=[0.0, 0.2]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.12
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.12
#  Rapp_ti_gs=[0.12, 1.39]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.88
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.39]
#  R_ti=0.88
#  papp_ti=0.6
#  tildepapp_ti=0.6
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33
#
# step 1, t_i=7.33
#  FAsapp_ti_gs(infty)=[0.0, 0.2]
#  FAsnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAsapp_ti(infty)=0.12
#  FAsnoapp_ti(infty)=0.12
#  FAs_ti(infty)=0.12
#  FAapp_ti_gs(infty)=[0.09, 0.27]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.2
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.17
#  FTapp_ti_gs(infty)=[0.09, 0.27]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.2
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.17
#  Rapp_ti_gs=[0.11, 1.28]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.81
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.32]
#  R_ti=0.84
#  papp_ti=0.6
#  tildepapp_ti=0.58
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33
#
# step 2, t_i=14.65
#  FAsapp_ti_gs(infty)=[0.0, 0.2]
#  FAsnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAsapp_ti(infty)=0.12
#  FAsnoapp_ti(infty)=0.12
#  FAs_ti(infty)=0.12
#  FAapp_ti_gs(infty)=[0.12, 0.3]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.23
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.18
#  FTapp_ti_gs(infty)=[0.12, 0.3]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.23
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.18
#  Rapp_ti_gs=[0.11, 1.24]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.79
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.3]
#  R_ti=0.83
#  papp_ti=0.6
#  tildepapp_ti=0.57
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33
#
# step 3, t_i=21.98
#  FAsapp_ti_gs(infty)=[0.0, 0.2]
#  FAsnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAsapp_ti(infty)=0.12
#  FAsnoapp_ti(infty)=0.12
#  FAs_ti(infty)=0.12
#  FAapp_ti_gs(infty)=[0.13, 0.31]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.24
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.19
#  FTapp_ti_gs(infty)=[0.13, 0.31]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.24
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.19
#  Rapp_ti_gs=[0.11, 1.23]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.78
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.29]
#  R_ti=0.82
#  papp_ti=0.6
#  tildepapp_ti=0.57
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33
#
# step 4, t_i=29.31
#  FAsapp_ti_gs(infty)=[0.0, 0.2]
#  FAsnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAsapp_ti(infty)=0.12
#  FAsnoapp_ti(infty)=0.12
#  FAs_ti(infty)=0.12
#  FAapp_ti_gs(infty)=[0.13, 0.31]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.24
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.19
#  FTapp_ti_gs(infty)=[0.13, 0.31]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.24
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.19
#  Rapp_ti_gs=[0.11, 1.22]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.78
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.29]
#  R_ti=0.82
#  papp_ti=0.6
#  tildepapp_ti=0.57
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33
#
# step 5, t_i=36.63
#  FAsapp_ti_gs(infty)=[0.0, 0.2]
#  FAsnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAsapp_ti(infty)=0.12
#  FAsnoapp_ti(infty)=0.12
#  FAs_ti(infty)=0.12
#  FAapp_ti_gs(infty)=[0.14, 0.31]
#  FAnoapp_ti_gs(infty)=[0.0, 0.2]
#  FAapp_ti(infty)=0.24
#  FAnoapp_ti(infty)=0.12
#  FA_ti(infty)=0.19
#  FTapp_ti_gs(infty)=[0.14, 0.31]
#  FTnoapp_ti_gs(infty)=[0.0, 0.2]
#  FTapp_ti(infty)=0.24
#  FTnoapp_ti(infty)=0.12
#  FT_ti(infty)=0.19
#  Rapp_ti_gs=[0.11, 1.22]
#  Rnoapp_ti_gs=[0.12, 1.39]
#  Rapp_ti=0.78
#  Rnoapp_ti=0.88
#  R_ti_gs=[0.12, 1.29]
#  R_ti=0.82
#  papp_ti=0.6
#  tildepapp_ti=0.57
#  p_gs=[0.4, 0.6]
#  tildep_ti_gs=[0.06, 0.94]
#  E(tauC_ti)=7.33

# %%
plot_time_evolution(step_data_list=step_data_list)
